# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
file_loc = "C:\\Users\\Hemant\\Documents\\Data Analysis Practise\\Projects\\Datasets\\kc_house_data.csv"
data = pd.read_csv(file_loc)
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ## Checking for missing values

# %%
# Finding Missing values
data.isnull().sum() 

# There are no missing values in the dataset
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Checking the price variance with the # of bedrooms
fig = plt.figure(figsize = (8,6))
ax = plt.subplot(111)
sns.scatterplot(data=data, x = "bedrooms", y = "price")
plt.show()

# %% [markdown]
# Prices are maximum for a 5 or 6 bedroom house. Clearly, >30 bedrooms is an outlier. So, we can eliminate that record

# %%
# Checking the price variance with the # of batchrooms
fig = plt.figure(figsize = (8,6))
ax = plt.subplot(111)
sns.scatterplot(data=data, x = "bathrooms", y = "price")
plt.show()

# %% [markdown]
# The prices are higher as the number of bathrooms are more. However, there is a high dispersion of the price for bedrooms.
# For example, for a house with 4 bathrooms, the price ranges from \\$100K to \\$3.1M

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Plotting a scatter_matrix to see the variation in price with other numerial attribs
from pandas.plotting import scatter_matrix

attribs_to_check = ["price", "bedrooms", "bathrooms","floors", "sqft_living", "sqft_lot", "sqft_above", "sqft_basement" ]

# %%
scatter_matrix(data[attribs_to_check], figsize = (15,15))
plt.show()

# %% [markdown]
# Observations:
# 1. Price varies directly proportional woth bathrooms, Living area, area of lot, sqt above and size of the basement
# 2. There is also multicollinearity between the independent variables as well. For example, Sft_living and sft_above and sft_basement
#
# Let us see the correlation coeff in a heat_map

# %%
plt.figure(figsize= (8,8))
sns.heatmap(data[attribs_to_check].corr(), annot = True, cmap = "RdYlBu")
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# Observations:
# 1. Price is not significantly correlated with bedroomm, floors and lot area. So, it is safe to drop these attributes
# 2. Prices varies significantly with number of bathrooms, living area and area excluding basement. However, the number of bathrooms is highly correlated with living area and area excl. basement
# 3. Area exluding basement is obviously correlated with the total area.
#
# 4. Combinations to explore:
#     * living Area per floor
#     * bedrooms per floor
#     * Remaining Lot area

# %%
# data["living_area_per_floor"] = data["sqft_living"] /  data["floors"]
# data["bedrooms_per_floor"] = data["bedrooms"] /  data["floors"]
# data["remaining_lot_area"] = data["sqft_lot"] /  data["sqft_living"]

# %%
# attribs_to_check.append("living_area_per_floor")
# attribs_to_check.append("bedrooms_per_floor")
# attribs_to_check.append("remaining_lot_area")

# %%
attribs_to_check
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'floors',
#  'sqft_living',
#  'sqft_lot',
#  'sqft_above',
#  'sqft_basement']

# %%
plt.figure(figsize= (10,10))
sns.heatmap(data[attribs_to_check].corr(), annot = True, cmap = "RdYlBu")
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# We can see that after adding the new columns, the price less corelated with them. So, let us not add these columns in the dataset. We can also see that the sqft_living is more corrleated that sqft_above. We should choose any one of these as they are corelated with themselves.
#
# So, if we are to choose the features, we can choose the ones that have correlation coeff > 0.5 with the price
# i.e. bathrooms, sfr_living.
#
# One more thing we can check is to see is the age of the flats and if renovation has any effect on the price

# %%
# data.drop(['living_area_per_floor',
#  'bedrooms_per_floor',
#  'remaining_lot_area'], axis = 1, inplace = True)

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# In order to get the age of the flat when purchased, let us :
# 1. take the year of purchase from the date
# 2. subtract rom the yr_built

# %%
data["age"] = data["date"].str[0:4].astype(int) - data["yr_built"]
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
plt.figure(figsize= (10,10))
sns.heatmap(data[attribs_to_check].corr(), annot = True, cmap = "RdYlBu")
plt.yticks(rotation = 0)
plt.show()

# %% [markdown]
# The agre does not seem to be corelated with the price. So,the final indpendent vriable to consider = bathrooms ans sft_living

# %%
X = data[["bathrooms", "sqft_living"]].values
y = data["price"].values

# %%
# Standar Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[-1.44746357, -0.97983502],
#        [ 0.1756067 ,  0.53363434],
#        [-1.44746357, -1.42625404],
#        ...,
#        [-1.77207762, -1.15404732],
#        [ 0.50022075, -0.52252773],
#        [-1.77207762, -1.15404732]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 23, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
lin_reg = LinearRegression()

lin_reg.fit(X_train, y_train)

# Let us test in the train data itself to see how well it understood the data
y_pred_train = lin_reg.predict(X_train)

mae_train = mean_absolute_error(y_pred_train, y_train)
mse_train = np.sqrt(mean_squared_error(y_pred_train, y_train))
mae_train, mse_train
# Out:
# (175420.57551550036, 265337.84352990106)

# %%
y_pred = lin_reg.predict(X_test)

# %%
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)

mae = mean_absolute_error(y_pred, y_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))
mae, mse
# Out:
# (169825.31423552267, 245282.28652129648)

# %% [markdown]
# Poor score - The +- 170000 range of prediction error is too huge.. Clearly, underfitting. Let us select all teh numerical attributes and the fit a regression line

# %%
data_num = data._get_numeric_data().drop("id", axis = 1)
data_num.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
X = data_num.iloc[:,1:].values
y = data_num.iloc[:,0].values

# %%
# Standar Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[-0.39873715, -1.44746357, -0.97983502, ..., -0.9433552 ,
#         -0.26071541,  0.53386491],
#        [-0.39873715,  0.1756067 ,  0.53363434, ..., -0.43268619,
#         -0.18786773,  0.67003599],
#        [-1.47395936, -1.44746357, -1.42625404, ...,  1.07013975,
#         -0.17237524,  1.31684861],
#        ...,
#        [-1.47395936, -1.77207762, -1.15404732, ..., -1.41025258,
#         -0.39414129, -1.30444465],
#        [-0.39873715,  0.50022075, -0.52252773, ..., -0.8412214 ,
#         -0.42051149, -1.10018803],
#        [-1.47395936, -1.77207762, -1.15404732, ..., -1.41025258,
#         -0.41794772, -1.27040188]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state= 23, test_size = 0.2)

# Training accuracy
lin_reg.fit(X_train, y_train)
y_pred_train = lin_reg.predict(X_train)

mae = mean_absolute_error(y_pred_train, y_train)
mse = np.sqrt(mean_squared_error(y_pred_train, y_train))

mae, mse
# Out:
# (127250.49603123739, 204326.53153094507)

# %%
lin_reg.fit(X_train, y_train)
y_pred = lin_reg.predict(X_test)

mae = mean_absolute_error(y_pred, y_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))

mae, mse
# Out:
# (122475.36982707282, 185546.46837269308)

# %%
lin_reg.coef_
# Out:
# array([-3.65228652e+04,  4.31550382e+04,  1.14223872e+02,  1.24495611e-01,
#         7.25267581e+03,  5.87230194e+05,  5.25436703e+04,  2.59924889e+04,
#         9.56417898e+04,  7.11547376e+01,  4.30691347e+01,  2.63563050e+04,
#         2.28686864e+01, -5.96196820e+02,  6.09576215e+05, -2.16239741e+05,
#         1.89518976e+01, -3.58875047e-01,  2.90105704e+04])

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
ridge = Ridge(alpha = 0.5)
ridge.fit(X_train, y_train)

y_train_pred = ridge.predict(X_train)

mae = mean_absolute_error(y_train_pred, y_train)
mse = np.sqrt(mean_squared_error(y_train_pred, y_train))

mae, mse
# Out:
# (127240.41699567999, 204326.69637465317)

# %%
y_pred = ridge.predict(X_test)

mae = mean_absolute_error(y_pred, y_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))
mae, mse
# Out:
# (122467.06863589298, 185542.98621775143)

# %%
from sklearn.tree import DecisionTreeRegressor
dctree_reg = DecisionTreeRegressor(random_state = 23)

dctree_reg.fit(X_train, y_train)

y_train_pred = dctree_reg.predict(X_train)

mae = mean_absolute_error(y_train_pred, y_train)
mse = np.sqrt(mean_squared_error(y_train_pred, y_train))

mae, mse
# Out:
# (129.41260844418738, 2798.494458951861)

# %%
y_pred = dctree_reg.predict(X_test)

mae = mean_absolute_error(y_pred, y_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))
mae, mse
# Out:
# (98792.42250751793, 171878.50910201902)

# %%
# Overfitting - High Accuracy in Training model but low accuracy in test

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomial_features = PolynomialFeatures(degree = 2)
X_poly = polynomial_features.fit_transform(X_train)


lin_reg.fit(X_poly, y_train)
y_pred_train = lin_reg.predict(X_poly)

mae = mean_absolute_error(y_pred_train, y_train)
mse = np.sqrt(mean_squared_error(y_pred_train, y_train))

mae, mse
# Out:
# (98106.8122093942, 151425.68878223427)

# %%
X_test_poly = polynomial_features.fit_transform(X_test)

y_test = lin_reg.predict(X_test_poly)

mae = mean_absolute_error(y_pred, y_test)
mse = np.sqrt(mean_squared_error(y_pred, y_test))

mae, mse
# Out:
# (108576.92460756877, 168480.89408696187)
